# %%
import numpy as np
import matplotlib.pyplot as plt

from analytical.transiente_R1d import radial_trans_1d_FP


# parameters

p0=25e6                 # pressão inicial [Pa]
qw=100/86400            # vazão [m³/s] = 100 m³/dia
h=20                    # espessura [m]
k=100*9.869233e-16      # permeabilidade [m²] = 100 mD
re=500                  # raio externo [m]
rw=0.1                  # raio do poço [m]
phi=0.20              # porosidade [-]
ct=1e-9                 # compressibilidade total [1/Pa]
mu=2e-3                  # viscosidade [Pa.s] = 2 cP
t_final=30*86400        # 30 dias em segundos


r,t,R,T,P=radial_trans_1d_FP(p0, qw, h, k, phi, ct, mu, t_final, rw, re)

# P em função de r

t_escolhido=10*86400

indice_t=np.argmin(np.abs(t-t_escolhido))

plt.plot(r,P[indice_t,:]/1e6)

plt.xlabel('r [m]')
plt.ylabel('P [MPa]')
plt.title(f'Pressão em função de r - t={t[indice_t]/86400:.1f} dias')

plt.grid()
plt.show()

# P em função de t

r_escolhido=100

indice_r=np.argmin(np.abs(r-r_escolhido))

plt.plot(t/86400,P[:,indice_r]/1e6)

plt.xlabel('t [dias]')
plt.ylabel('P [MPa]')
plt.title(f'Pressão em função de t - r={r[indice_r]:.1f} m')

plt.grid()
plt.show()
# Out:
# C:\Users\brend\OneDrive\Documentos\Faculdade\SimRes\src\analytical\transiente_R1d.py:13: RuntimeWarning: divide by zero encountered in divide
#   P = p0 - (qw * mu)/(4 * np.pi * k * h) * exp1((phi * mu * ct * R**2)/(4 * k * T))
